# %%
# If running in Google Colab, mount drive
print('Check if running in Colab...')
try:
    from google.colab import drive
    print('Running in Colab!')
    drive.mount('/content/drive')
    # %cd '/content/drive/My Drive/CIL-FS20'
except ImportError:
    print('Running locally!')

    #Check python version
    from platform import python_version
    print('Current python version: {}'.format(python_version()))

    # Check available GPUs
    import tensorflow as tf
    no_GPUs_available = len(tf.config.experimental.list_physical_devices('GPU'))
    print("Number of GPUs Available: {}".format(no_GPUs_available))
# Out:
# Check if running in Colab...
# Running locally!
# Current python version: 3.7.5
# Number of GPUs Available: 1

# %%
import matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os,sys

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose, UpSampling2D, Cropping2D
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.merge import concatenate
from keras import optimizers
from keras.layers import BatchNormalization
from tensorflow.keras.metrics import MeanIoU
from keras import backend as K
from keras.backend import binary_crossentropy
import keras
import random
import tensorflow as tf
from sklearn.model_selection import train_test_split

from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from datetime import datetime

from mask_to_submission import masks_to_submission
import util

## Install the following packages
import imageio
from PIL import Image
import cv2
import natsort
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Constants

# %%
# Name of the current model
MODEL_NAME = 'fullyCNN_datagenerator_improved_unet_dropout'
IMG_WIDTH = 608
IMG_HEIGHT = 608
EPOCHS = 100
STEPS_PER_EPOCH = 1000
LEARNING_RATE = 0.0001
BATCH_SIZE = 2
rnd_seed = 4
np.random.seed(rnd_seed)

# %% [markdown]
# ## Load Images

# %%
training_image_dir = "training_images/images/"
training_label_dir = "training_images/groundtruth/"
test_image_dir = "test_images/normal/"

files_image = os.listdir(training_image_dir)
files_image = natsort.natsorted(files_image)
files_label = os.listdir(training_label_dir)
files_label = natsort.natsorted(files_label)
files_test = os.listdir(test_image_dir)
files_test = natsort.natsorted(files_test)
n = len(files_image)
n_test = len(files_test) 

# Load list of numpy arrays of training images and labels
print("Loading " + str(n) + " training images")
training_image_list = []
training_label_list = []
for i in range(n):
    print("Loading training image {:04d}\r".format(i)),
    training_image_list.append(imageio.imread(training_image_dir + files_image[i], pilmode="RGB"))
    training_label_list.append(imageio.imread(training_label_dir + files_label[i], pilmode="L"))

# Load list of numpy arrays of test images
print("Loading " + str(n_test) + " test images")
test_image_list = [imageio.imread(test_image_dir + files_test[i]) for i in range(n_test)]

print("TRAINING:")
print(training_image_list[0].shape)
print(training_label_list[0].shape)
print("TEST:")
print(test_image_list[0].shape)
# Out:
# Loading 2511 training images
# Loading training image 0000
# Loading training image 0001
# Loading training image 0002
# Loading training image 0003
# Loading training image 0004
# Loading training image 0005
# Loading training image 0006
# Loading training image 0007
# Loading training image 0008
# Loading training image 0009
# Loading training image 0010
# Loading training image 0011
# Loading training image 0012
# Loading training image 0013
# Loading training image 0014
# Loading training image 0015
# Loading training image 0016
# Loading training image 0017
# Loading training image 0018
# Loading training image 0019
# Loading training image 0020
# Loading training image 0021
# Loading training image 0022
# Loading training image 0023
# Loading training image 0024
# Loading training image 0025
# Loading training image 0026
# Loading training image 0027
# Loading training image 0028
# Loading training image 0029
# Loading training image 0030
# Loading training image 0031
# Loading training image 0032
# Loading training image 0033
# Loading training image 0034
# Loading training image 0035
# Loading training image 2410
# Loading training image 2411
# Loading training image 2412
# Loading training image 2413
# Loading training image 2414
# Loading training image 2415
# Loading training image 2416
# Loading training image 2417
# Loading training image 2418
# Loading training image 2419
# Loading training image 2420
# Loading training image 2421
# Loading training image 2422
# Loading training image 2423
# Loading training image 2424
# Loading training image 2425
# Loading training image 2426
# Loading training image 2427
# Loading training image 2428
# Loading training image 2429
# Loading training image 2430
# Loading training image 2431
# Loading training image 2432
# Loading training image 2433
# Loading training image 2434
# Loading training image 2435
# Loading training image 2436
# Loading training image 2437
# Loading training image 2438
# Loading training image 2439
# Loading training image 2440
# Loading training image 2441
# Loading training image 2442
# Loading training image 2443
# Loading training image 2444
# Loading training image 2445
# Loading training image 2446
# Loading training image 2447
# Loading training image 2448
# Loading training image 2449
# Loading training image 2450
# Loading training image 2451
# Loading training image 2452
# Loading training image 2453
# Loading training image 2454
# Loading training image 2455
# Loading training image 2456
# Loading training image 2457
# Loading training image 2458
# Loading training image 2459
# Loading training image 2460
# Loading training image 2461
# Loading training image 2462
# Loading training image 2463
# Loading training image 2464
# Loading training image 2465
# Loading training image 2466
# Loading training image 2467
# Loading training image 2468
# Loading training image 2469
# Loading training image 2470
# Loading training image 2471
# Loading training image 2472
# Loading training image 2473
# Loading training image 2474
# Loading training image 2475
# Loading training image 2476
# Loading training image 2477
# Loading training image 2478
# Loading training image 2479
# Loading training image 2480
# Loading training image 2481
# Loading training image 2482
# Loading training image 2483
# Loading training image 2484
# Loading training image 2485
# Loading training image 2486
# Loading training image 2487
# Loading training image 2488
# Loading training image 2489
# Loading training image 2490
# Loading training image 2491
# Loading training image 2492
# Loading training image 2493
# Loading training image 2494
# Loading training image 2495
# Loading training image 2496
# Loading training image 2497
# Loading training image 2498
# Loading training image 2499
# Loading training image 2500
# Loading training image 2501
# Loading training image 2502
# Loading training image 2503
# Loading training image 2504
# Loading training image 2505
# Loading training image 2506
# Loading training image 2507
# Loading training image 2508
# Loading training image 2509
# Loading training image 2510
# Loading 94 test images
# TRAINING:
# (608, 608, 3)
# (608, 608)
# TEST:
# (608, 608, 3)

# %% [markdown]
# ## Padd Images
# Training images have size 400x400 and test images have size 608x608. So we need to pad training images to same size,
# for that I use mirror padding for now.

# %%
# Mirror padd all training images to get same size as test images
training_image_padded_list = []
training_label_padded_list = []
for i in range(n):
    training_image = training_image_list[i]
    training_label = training_label_list[i]
    height, width, _ = training_image.shape
    pad_y = int((IMG_HEIGHT - height) / 2)
    pad_x = int((IMG_WIDTH - height) / 2)
    training_image_padded_list.append(cv2.copyMakeBorder(training_image,pad_y,pad_y,pad_x,pad_x,cv2.BORDER_REFLECT))
    training_label_padded_list.append(cv2.copyMakeBorder(training_label,pad_y,pad_y,pad_x,pad_x,cv2.BORDER_REFLECT))

# Plot random Sample of images
index = random.randint(0, n-1)
num_samples = 5

f = plt.figure(figsize = (15, 25))
for i in range(1, num_samples*4, 4):
  index = random.randint(0, n-1)

  f.add_subplot(num_samples, 4, i)
  plt.imshow(training_image_list[index])
  plt.title("Original Image")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+1)
  plt.imshow(training_image_padded_list[index])
  plt.title("Padded Image")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+2)
  plt.imshow(np.squeeze(training_label_list[index]))
  plt.title("Original Label")
  plt.axis('off')

  f.add_subplot(num_samples, 4, i+3)
  plt.imshow(np.squeeze(training_label_padded_list[index]))
  plt.title("Padded Label")
  plt.axis('off')

plt.show()

# Convert image lists to numpy arrays for further processing
training_image = np.array(training_image_padded_list)
training_label = np.expand_dims(np.array(training_label_padded_list), -1)
test_image = np.array(test_image_list)
print(training_image.shape)
print(training_label.shape)

# Delete unused variables, hopefully this frees up some RAM
del training_image_list
del training_label_list
del training_image_padded_list
del training_label_padded_list
# Out:
# (2511, 608, 608, 3)
# (2511, 608, 608, 1)

# %%
# Make sure label masks only have values 1 or zero
#thresh_val = 0.5
#training_label = (training_label > thresh_val).astype(np.uint8)
#training_label = training_label/255
training_label = training_label.astype(np.float32)
#print(np.unique(training_label, return_counts=True, axis=None))
print(training_label.dtype)

# Get a validation set
training_image, validation_image, training_label, validation_label = train_test_split(
    training_image, training_label, test_size=0.1, random_state=rnd_seed)

# Rescale validation images/labels and test images because generator will do the same with training data
validation_image = validation_image/255.0
validation_label = validation_label/255.0
validation_image = validation_image.astype(np.float32)
validation_label = validation_label.astype(np.float32)
print(validation_image.dtype)
test_image = test_image/255.0
test_image = test_image.astype(np.float32)
print(test_image.dtype)
# Out:
# float32
# float32
# float32

# %% [markdown]
# ## Augment Training Data
#
# We use the Keras Data Generator to augment our training data online while training. This is necessary because of memory consumption.

# %%
# We create an instance for the training images, training labels and test images
data_gen_args = dict(rescale=1.0/255.0,
                     #rotation_range=360,
                     #width_shift_range=0.05,
                     #height_shift_range=0.05,
                     #zoom_range=0.05,
                     #shear_range=0.05,
                     horizontal_flip=True,
                     vertical_flip=True,
                     fill_mode='reflect')

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

# Provide the same seed and keyword arguments to the fit and flow methods
seed = 1
image_generator = image_datagen.flow(
    training_image,
    batch_size=BATCH_SIZE,
    #save_to_dir="training_images_augmented/images/",
    #save_prefix="",
    #save_format="png",
    seed=seed)
mask_generator = mask_datagen.flow(
    training_label,
    batch_size=BATCH_SIZE,
    #save_to_dir="training_images_augmented/groundtruth/",
    #save_prefix="",
    #save_format="png",
    seed=seed)

# Combine generators into one which yields image and masks
train_generator = zip(image_generator, mask_generator)

# %% [markdown]
# ## Loss Function and Accuracy Metric
# - Accuracy: Intersection of prediction to label image over Union
# - Loss :
#     - Dice Coef Loss (https://arxiv.org/pdf/1606.04797v1.pdf)
#     - Soft Dice Loss (Measure of interleaving of prediction image and label image)
#     - Jaccard Distance
#
# Source: https://towardsdatascience.com/metrics-to-evaluate-your-semantic-segmentation-model-6bcb99

# %%
from keras import backend as K

def iou_coef(y_true, y_pred, smooth=1):
    intersection = K.sum(K.abs(y_true * y_pred), axis=[1,2,3])
    union = K.sum(y_true,[1,2,3])+K.sum(y_pred,[1,2,3])-intersection
    iou = K.mean((intersection + smooth) / (union + smooth), axis=0)
    return iou

def dice_coef(y_true, y_pred, smooth=1):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    """
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    return (2. * intersection + smooth) / (K.sum(K.square(y_true),-1) + K.sum(K.square(y_pred),-1) + smooth)

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

def soft_dice_coef(y_true, y_pred, smooth = 1):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def soft_dice_loss(y_true, y_pred):
    return 1-soft_dice_coef(y_true, y_pred)

def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.abs(y_true) + K.abs(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac) * smooth

def jaccard_coef(y_true, y_pred, smooth = 1e-12):
    intersection = K.sum(y_true * y_pred, axis=[0, 1, 2])
    sum_ = K.sum(y_true + y_pred, axis=[0, 1, 2])

    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    return K.mean(jac)

def jaccard_coef_int(y_true, y_pred):
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))

    intersection = K.sum(y_true * y_pred_pos, axis=[0, -1, -2])
    sum_ = K.sum(y_true + y_pred_pos, axis=[0, -1, -2])

    jac = (intersection + smooth) / (sum_ - intersection + smooth)

    return K.mean(jac)

def combined_loss(y_true, y_pred):
    return -K.log(jaccard_coef(y_true, y_pred)) + binary_crossentropy(y_pred, y_true)

# %% [markdown]
# ## Model: Fully CNN built in Keras

# %%
inputs = Input((IMG_HEIGHT, IMG_WIDTH, 3))

conv1 = Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(inputs)
conv1 = BatchNormalization()(conv1)
conv1 = Dropout(0.1) (conv1)
conv1 = keras.layers.advanced_activations.ELU()(conv1)
conv1 = Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(conv1)
conv1 = BatchNormalization()(conv1)
conv1 = keras.layers.advanced_activations.ELU()(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(pool1)
conv2 = BatchNormalization()(conv2)
conv2 = Dropout(0.1) (conv2)
conv2 = keras.layers.advanced_activations.ELU()(conv2)
conv2 = Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(conv2)
conv2 = BatchNormalization()(conv2)
conv2 = keras.layers.advanced_activations.ELU()(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(pool2)
conv3 = BatchNormalization()(conv3)
conv3 = Dropout(0.1) (conv3)
conv3 = keras.layers.advanced_activations.ELU()(conv3)
conv3 = Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(conv3)
conv3 = BatchNormalization()(conv3)
conv3 = keras.layers.advanced_activations.ELU()(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(pool3)
conv4 = BatchNormalization()(conv4)
conv4 = Dropout(0.1) (conv4)
conv4 = keras.layers.advanced_activations.ELU()(conv4)
conv4 = Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(conv4)
conv4 = BatchNormalization()(conv4)
conv4 = keras.layers.advanced_activations.ELU()(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(pool4)
conv5 = BatchNormalization()(conv5)
conv5 = Dropout(0.1) (conv5)
conv5 = keras.layers.advanced_activations.ELU()(conv5)
conv5 = Conv2D(512, (3, 3), padding='same', kernel_initializer='he_uniform')(conv5)
conv5 = BatchNormalization()(conv5)
conv5 = keras.layers.advanced_activations.ELU()(conv5)

up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(up6)
conv6 = BatchNormalization()(conv6)
conv6 = Dropout(0.1) (conv6)
conv6 = keras.layers.advanced_activations.ELU()(conv6)
conv6 = Conv2D(256, (3, 3), padding='same', kernel_initializer='he_uniform')(conv6)
conv6 = BatchNormalization()(conv6)
conv6 = keras.layers.advanced_activations.ELU()(conv6)

up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(up7)
conv7 = BatchNormalization()(conv7)
conv7 = Dropout(0.1) (conv7)
conv7 = keras.layers.advanced_activations.ELU()(conv7)
conv7 = Conv2D(128, (3, 3), padding='same', kernel_initializer='he_uniform')(conv7)
conv7 = BatchNormalization()(conv7)
conv7 = keras.layers.advanced_activations.ELU()(conv7)

up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(up8)
conv8 = BatchNormalization()(conv8)
conv8 = Dropout(0.1) (conv8)
conv8 = keras.layers.advanced_activations.ELU()(conv8)
conv8 = Conv2D(64, (3, 3), padding='same', kernel_initializer='he_uniform')(conv8)
conv8 = BatchNormalization()(conv8)
conv8 = keras.layers.advanced_activations.ELU()(conv8)

up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(up9)
conv9 = BatchNormalization()(conv9)
conv9 = Dropout(0.1) (conv9)
conv9 = keras.layers.advanced_activations.ELU()(conv9)
conv9 = Conv2D(32, (3, 3), padding='same', kernel_initializer='he_uniform')(conv9)
#crop9 = Cropping2D(cropping=((16, 16), (16, 16)))(conv9)
#conv9 = BatchNormalization()(crop9)
conv9 = BatchNormalization() (conv9)
conv9 = keras.layers.advanced_activations.ELU()(conv9)
conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=inputs, outputs=conv10)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 608, 608, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 608, 608, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 608, 608, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 608, 608, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# elu_1 (ELU)                     (None, 608, 608, 32) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 608, 608, 32) 9248        elu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 608, 608, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# elu_2 (ELU)                     (None, 608, 608, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 304, 304, 32) 0           elu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 304, 304, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 304, 304, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 304, 304, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# elu_3 (ELU)                     (None, 304, 304, 64) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 304, 304, 64) 36928       elu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 304, 304, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# elu_4 (ELU)                     (None, 304, 304, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 152, 152, 64) 0           elu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 152, 152, 128 73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 152, 152, 128 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 152, 152, 128 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# elu_5 (ELU)                     (None, 152, 152, 128 0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 152, 152, 128 147584      elu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 152, 152, 128 512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# elu_6 (ELU)                     (None, 152, 152, 128 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 76, 76, 128)  0           elu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 76, 76, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 76, 76, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 76, 76, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# elu_7 (ELU)                     (None, 76, 76, 256)  0           dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 76, 76, 256)  590080      elu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 76, 76, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# elu_8 (ELU)                     (None, 76, 76, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 38, 38, 256)  0           elu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 38, 38, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 38, 38, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 38, 38, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# elu_9 (ELU)                     (None, 38, 38, 512)  0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 38, 38, 512)  2359808     elu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 38, 38, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# elu_10 (ELU)                    (None, 38, 38, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 76, 76, 512)  0           elu_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 76, 76, 768)  0           up_sampling2d_1[0][0]
#                                                                  elu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 76, 76, 256)  1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 76, 76, 256)  1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 76, 76, 256)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# elu_11 (ELU)                    (None, 76, 76, 256)  0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 76, 76, 256)  590080      elu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 76, 76, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# elu_12 (ELU)                    (None, 76, 76, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 152, 152, 256 0           elu_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 152, 152, 384 0           up_sampling2d_2[0][0]
#                                                                  elu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 152, 152, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 152, 152, 128 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 152, 152, 128 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# elu_13 (ELU)                    (None, 152, 152, 128 0           dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 152, 152, 128 147584      elu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 152, 152, 128 512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# elu_14 (ELU)                    (None, 152, 152, 128 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 304, 304, 128 0           elu_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 304, 304, 192 0           up_sampling2d_3[0][0]
#                                                                  elu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 304, 304, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 304, 304, 64) 256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 304, 304, 64) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# elu_15 (ELU)                    (None, 304, 304, 64) 0           dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 304, 304, 64) 36928       elu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 304, 304, 64) 256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# elu_16 (ELU)                    (None, 304, 304, 64) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 608, 608, 64) 0           elu_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 608, 608, 96) 0           up_sampling2d_4[0][0]
#                                                                  elu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 608, 608, 32) 27680       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 608, 608, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 608, 608, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# elu_17 (ELU)                    (None, 608, 608, 32) 0           dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 608, 608, 32) 9248        elu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 608, 608, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# elu_18 (ELU)                    (None, 608, 608, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 608, 608, 1)  33          elu_18[0][0]
# ==================================================================================================
# Total params: 7,858,433
# Trainable params: 7,852,545
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks for Observations

# %%
#tbc=TensorBoardColab()
model_path = "./Models/{}_model.h5".format(MODEL_NAME)
checkpointer = ModelCheckpoint(model_path,
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)
csv_logger = CSVLogger("./Logs/{}_log.csv".format(MODEL_NAME), separator=',', append=False)
lr_reducer = ReduceLROnPlateau(monitor='val_loss',
                               factor=0.1,
                               patience=6,
                               verbose=1,
                               epsilon=1e-4)
early_stopper = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, verbose=1)
# Out:
# /home/rmenta/.local/lib/python3.7/site-packages/keras/callbacks/callbacks.py:998: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# ## Model Training

# %%
#opt = keras.optimizers.adam(LEARNING_RATE)
opt = keras.optimizers.Nadam(lr=LEARNING_RATE)
model.compile(
      optimizer=opt,
      loss=combined_loss,
      metrics=[iou_coef])

# %%
model = load_model("./Models/{}_model.h5".format(MODEL_NAME), custom_objects={'dice_coef_loss': dice_coef_loss, 'iou_coef': iou_coef, 'combined_loss': combined_loss})
history = model.fit_generator(train_generator,
                              validation_data =(validation_image, validation_label),
                              steps_per_epoch=STEPS_PER_EPOCH,
                              epochs=EPOCHS,
                              callbacks = [checkpointer, csv_logger, lr_reducer, early_stopper])
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 455s 455ms/step - loss: 0.7322 - iou_coef: 0.6453 - val_loss: 0.7608 - val_iou_coef: 0.6140
#
# Epoch 00001: val_loss improved from inf to 0.76079, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 2/100
# 1000/1000 [==============================] - 448s 448ms/step - loss: 0.7245 - iou_coef: 0.6437 - val_loss: 0.7563 - val_iou_coef: 0.6161
#
# Epoch 00002: val_loss improved from 0.76079 to 0.75633, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 3/100
# 1000/1000 [==============================] - 451s 451ms/step - loss: 0.7176 - iou_coef: 0.6475 - val_loss: 0.7521 - val_iou_coef: 0.6186
#
# Epoch 00003: val_loss improved from 0.75633 to 0.75214, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 4/100
# 1000/1000 [==============================] - 458s 458ms/step - loss: 0.7182 - iou_coef: 0.6459 - val_loss: 0.7529 - val_iou_coef: 0.6175
#
# Epoch 00004: val_loss did not improve from 0.75214
# Epoch 5/100
# 1000/1000 [==============================] - 471s 471ms/step - loss: 0.7175 - iou_coef: 0.6459 - val_loss: 0.7432 - val_iou_coef: 0.6214
#
# Epoch 00005: val_loss improved from 0.75214 to 0.74315, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 6/100
# 1000/1000 [==============================] - 479s 479ms/step - loss: 0.7248 - iou_coef: 0.6436 - val_loss: 0.7514 - val_iou_coef: 0.6173
#
# Epoch 00006: val_loss did not improve from 0.74315
# Epoch 7/100
# 1000/1000 [==============================] - 447s 447ms/step - loss: 0.7161 - iou_coef: 0.6494 - val_loss: 0.7478 - val_iou_coef: 0.6180
#
# Epoch 00007: val_loss did not improve from 0.74315
# Epoch 8/100
# 1000/1000 [==============================] - 446s 446ms/step - loss: 0.7172 - iou_coef: 0.6466 - val_loss: 0.7568 - val_iou_coef: 0.6135
#
# Epoch 00008: val_loss did not improve from 0.74315
# Epoch 9/100
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.7089 - iou_coef: 0.6499 - val_loss: 0.7620 - val_iou_coef: 0.6150
#
# Epoch 00009: val_loss did not improve from 0.74315
# Epoch 10/100
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.7053 - iou_coef: 0.6502 - val_loss: 0.7395 - val_iou_coef: 0.6213
#
# Epoch 00010: val_loss improved from 0.74315 to 0.73947, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 11/100
# 1000/1000 [==============================] - 445s 445ms/step - loss: 0.7279 - iou_coef: 0.6454 - val_loss: 0.7393 - val_iou_coef: 0.6207
#
# Epoch 00011: val_loss improved from 0.73947 to 0.73926, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 12/100
# 1000/1000 [==============================] - 443s 443ms/step - loss: 0.7040 - iou_coef: 0.6482 - val_loss: 0.7624 - val_iou_coef: 0.6137
#
# Epoch 00012: val_loss did not improve from 0.73926
# Epoch 13/100
# 1000/1000 [==============================] - 454s 454ms/step - loss: 0.7067 - iou_coef: 0.6533 - val_loss: 0.7280 - val_iou_coef: 0.6262
#
# Epoch 00013: val_loss improved from 0.73926 to 0.72796, saving model to ./Models/fullyCNN_datagenerator_improved_unet_dropout_model.h5
# Epoch 14/100
# 1000/1000 [==============================] - 457s 457ms/step - loss: 0.7009 - iou_coef: 0.6532 - val_loss: 0.7343 - val_iou_coef: 0.6249
#
# Epoch 00014: val_loss did not improve from 0.72796
# Epoch 15/100
# 1000/1000 [==============================] - 459s 459ms/step - loss: 0.7055 - iou_coef: 0.6509 - val_loss: 0.7381 - val_iou_coef: 0.6232
#
# Epoch 00015: val_loss did not improve from 0.72796
# Epoch 16/100
# 1000/1000 [==============================] - 450s 450ms/step - loss: 0.6890 - iou_coef: 0.6523 - val_loss: 0.7362 - val_iou_coef: 0.6217
#
# Epoch 00016: val_loss did not improve from 0.72796
# Epoch 17/100
# 1000/1000 [==============================] - 445s 445ms/step - loss: 0.7084 - iou_coef: 0.6521 - val_loss: 0.7483 - val_iou_coef: 0.6203
#
# Epoch 00017: val_loss did not improve from 0.72796
# Epoch 18/100
# 1000/1000 [==============================] - 428s 428ms/step - loss: 0.6943 - iou_coef: 0.6559 - val_loss: 0.7465 - val_iou_coef: 0.6192
#
# Epoch 00018: val_loss did not improve from 0.72796
# Epoch 19/100
# 1000/1000 [==============================] - 430s 430ms/step - loss: 0.7034 - iou_coef: 0.6539 - val_loss: 0.7470 - val_iou_coef: 0.6190
#
# Epoch 00019: val_loss did not improve from 0.72796
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# Epoch 20/100
# 1000/1000 [==============================] - 425s 425ms/step - loss: 0.6887 - iou_coef: 0.6566 - val_loss: 0.7465 - val_iou_coef: 0.6189
#
# Epoch 00020: val_loss did not improve from 0.72796
# Epoch 21/100
# 1000/1000 [==============================] - 425s 425ms/step - loss: 0.6871 - iou_coef: 0.6584 - val_loss: 0.7400 - val_iou_coef: 0.6215
#
# Epoch 00021: val_loss did not improve from 0.72796
# Epoch 22/100
# 1000/1000 [==============================] - 425s 425ms/step - loss: 0.6940 - iou_coef: 0.6563 - val_loss: 0.7358 - val_iou_coef: 0.6229
#
# Epoch 00022: val_loss did not improve from 0.72796
# Epoch 23/100
# 1000/1000 [==============================] - 425s 425ms/step - loss: 0.6972 - iou_coef: 0.6568 - val_loss: 0.7398 - val_iou_coef: 0.6214
#
# Epoch 00023: val_loss did not improve from 0.72796
# Epoch 00023: early stopping

# %%
# Show a training report
training_info = pd.read_csv('./Logs/{}_log.csv'.format(MODEL_NAME), header=0)

acc1, = plt.plot(training_info['epoch'], training_info['iou_coef'])
acc2, = plt.plot(training_info['epoch'], training_info['val_iou_coef'])
plt.legend([acc1, acc2], ['Training IOU coef', 'Validation IOU coef'])
plt.xlabel('Epoch')
plt.ylim(0,0.1)
plt.grid(True)
plt.show()

loss1, = plt.plot(training_info['epoch'], training_info['loss'])
loss2, = plt.plot(training_info['epoch'], training_info['val_loss'])
plt.legend([acc1, acc2], ['Training Loss', 'Validation Loss'])                            
plt.xlabel('Epoch')
plt.ylim(0,0.1)
plt.grid(True)

plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
# Kaggle scores on validation images (mean score per image and overall mean score)
model = load_model("./Models/{}_model.h5".format(MODEL_NAME), custom_objects={'dice_coef_loss': dice_coef_loss, 'iou_coef': iou_coef, 'combined_loss': combined_loss})
y_pred = model.predict(validation_image, batch_size=4, verbose=1)
scores = util.validate_kaggle_score(validation_label, y_pred)
print(scores)
print(sum(scores)/len(scores))

# %%
model = load_model("./Models/{}_model.h5".format(MODEL_NAME), custom_objects={'dice_coef_loss': dice_coef_loss, 'iou_coef': iou_coef, 'combined_loss': combined_loss})
#model.evaluate(test_images, test_label)
predictions = model.predict(test_image, batch_size=4, verbose=1)
# Out:
# 94/94 [==============================] - 6s 59ms/step

# %%
thresh_val = 0.5
predicton_threshold = (predictions > thresh_val).astype(np.uint8)

index = random.randint(0, len(predictions)-1)
num_samples = 10

f = plt.figure(figsize = (15, 25))
for i in range(1, num_samples*3, 3):
  index = random.randint(0, len(predictions)-1)

  f.add_subplot(num_samples, 3, i)
  plt.imshow(test_image[index][:,:,0])
  plt.title("Image")
  plt.axis('off')

  f.add_subplot(num_samples, 3, i+1)
  plt.imshow(np.squeeze(predictions[index][:,:,0]))
  plt.title("Prediction")
  plt.axis('off')

  f.add_subplot(num_samples, 3, i+2)
  plt.imshow(np.squeeze(predicton_threshold[index][:,:,0]))
  plt.title("Thresholded at {}".format(thresh_val))
  plt.axis('off')

plt.show()

# %% [markdown]
# ## Create Submission File
# Multiply image by 255 and convert to unit8 before storing s.t. it gets read out correctly by mask_to_submission!

# %%
predictions = np.squeeze(predictions*255)
predictions = predictions.astype(np.uint8)
result_dir = './Results/Prediction_Images/{}/'.format(MODEL_NAME)
os.makedirs(result_dir, exist_ok=True)

#print(predictions.shape)
#[print(predictions[i].shape) for i in range(n_test)]

[imageio.imwrite(result_dir + files_test[i], predictions[i],) for i in range(n_test)]
files_predictions = os.listdir(result_dir)
files_predictions = [result_dir + files_predictions[i] for i in range(n_test)]
masks_to_submission('./Results/Submissions/{}.csv'.format(MODEL_NAME), *files_predictions)
print('Submission ready')
# Out:
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_211.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_49.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_10.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_136.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_92.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_177.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_76.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_64.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_23.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_80.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_51.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_9.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_14.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_108.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_139.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_162.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_143.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_29.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_129.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_154.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_54.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_69.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_222.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_157.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_151.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_152.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_107.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_123.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_191.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_218.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_221.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_90.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_159.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_79.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_186.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_128.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_65.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_105.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_216.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_223.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_21.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_215.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_161.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_41.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_27.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_61.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_169.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_40.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_176.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_145.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_208.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_207.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_153.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_138.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_115.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_168.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_131.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_200.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_187.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_155.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_192.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_15.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_25.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_7.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_170.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_189.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_196.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_190.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_175.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_202.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_130.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_8.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_205.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_142.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_121.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_12.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_122.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_124.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_106.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_36.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_201.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_11.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_93.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_219.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_116.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_26.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_220.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_206.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_140.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_50.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_137.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_144.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_204.png
# ./Results/Prediction_Images/fullyCNN_datagenerator_improved_unet_dropout/test_174.png
# Submission ready
